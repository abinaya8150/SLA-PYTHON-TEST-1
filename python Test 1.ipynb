# %%
#1) Swap the number without using third varible.
number="123456789"
print(number)
# Out:
# 123456789

# %%
number[::2]
# Out:
# '13579'

# %%
#2)  Display three string “Name”, “Is”, “James” as “Name ** Is ** James”
s1="Name"
s2="Is"
s3="James"
print(s1+'  '+s2+'  '+s3)
# Out:
# Name  Is  James

# %%
#3) How do you take an integer input from the user?
#->you can user input using input function()
#->it always input function return the string
#-> if need for integer convert str to int function
tamil=int(input("Enter your tamil mark :"))
english=int(input("Enter your english mark :"))
# Out:
# Enter your tamil mark :88
# Enter your english mark :99

# %%
#4) How do you print a variable inside a string?
print("Tamil mark is:{} ,English mark is {}".format(tamil,english))
# Out:
# Tamil mark is:88 ,English mark is 99

# %%
#5)How do you print a string multiple times? with an examples
a='abinaya ,'
print(a)
# Out:
# abinaya ,

# %%
a *10
# Out:
# 'abinaya ,abinaya ,abinaya ,abinaya ,abinaya ,abinaya ,abinaya ,abinaya ,abinaya ,abinaya ,'

# %%
#6) How do you print a string in reverse without using loops?
print(a[::-1])
# Out:
# , ayaniba

# %%
#7)Take two numbers as input and print their sum(user input)
line1 =int(input("enter the line 1:"))
line2 =int(input("enter the line 2:"))
# Out:
# enter the line 1:7
# enter the line 2:8

# %%
print(line1 +line2)
# Out:
# 15

# %%
#8) Take three numbers and print their average (user input)
a=7
b=3
c=2
print(a+b+c)
# Out:
# 12

# %%
print(12/3)
# Out:
# 4.0

# %%
#9)Take a percentage as input and print with a percentage sign
a="99%"
print(a)
# Out:
# 99%

# %%
#10) Take a sentence and print it in uppercase, lowercase, and title case
c="Have a Nice Day"
c.upper()
# Out:
# 'HAVE A NICE DAY'

# %%
c.lower()
# Out:
# 'have a nice day'

# %%
c.title()
# Out:
# 'Have A Nice Day'
